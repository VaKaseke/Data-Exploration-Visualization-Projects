# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Reading dataset

# %%
df=pd.read_csv("Crimes.csv")
df
# Out:
#             ID Case Number             Date                    Block  IUCR  \
# 0     10000092    HY189866  3/18/2015 19:44          047XX W OHIO ST  041A
# 1     10000094    HY190059  3/18/2015 23:00   066XX S MARSHFIELD AVE  4625
# 2     10000095    HY190052  3/18/2015 22:45    044XX S LAKE PARK AVE   486
# 3     10000096    HY190054  3/18/2015 22:30     051XX S MICHIGAN AVE   460
# 4     10000097    HY189976  3/18/2015 21:00         047XX W ADAMS ST  031A
# ...        ...         ...              ...                      ...   ...
# 4994  10010215    HY199560  3/26/2015 18:30  013XX S BLUE ISLAND AVE  1320
# 4995  10010216    HY199605  3/20/2015 14:00    043XX S LAKE PARK AVE  2820
# 4996  10010218    HY199430  3/22/2015 20:00         0000X E 121ST ST  1320
# 4997  10010219    HY199538  3/26/2015 18:15      083XX S STEWART AVE   860
# 4998  10010220    HY199623  3/26/2015 18:00          003XX W 51ST ST  031A
#
#          Primary Type              Description  \
# ...

# %% [markdown]
# # Sum of null values in each column

# %%
df.isnull().sum()
# Out:
# ID                       0
# Case Number              0
# Date                     0
# Block                    0
# IUCR                     0
# Primary Type             0
# Description              0
# Location Description    11
# Arrest                   0
# Domestic                 0
# Beat                     0
# District                 0
# Ward                     0
# Community Area           0
# FBI Code                 0
# X Coordinate            12
# Y Coordinate            12
# Year                     0
# Updated On               0
# Latitude                12
# Longitude               12
# Location                12
# dtype: int64

# %% [markdown]
# # Finding Data where Location has null values

# %%
filt=df['Location'].isnull()
df[filt]
# Out:
#             ID Case Number             Date                  Block  IUCR  \
# 21    10581023    HZ329792   9/1/2014 08:00        0000X E LAKE ST  1140
# 125    4755307    HM367521   1/23/2002 0:00  077XX S GREENWOOD AVE   840
# 1325   4757173    HM368193  5/22/2006 14:30     074XX N ROGERS AVE   910
# 1539   4759696    HM370403  10/24/2004 9:00      077XX S ESSEX AVE  1752
# 1603   4757685    HM368701   9/3/2004 19:00  111XX S VINCENNES AVE   870
# 1777   4757985    HM367001  9/29/2004 10:30    092XX S ASHLAND AVE  1120
# 2290   4759012    HM370837  5/24/2004 17:45     054XX S WABASH AVE   840
# 3918   4761793    HM369619   9/9/2004 08:00   059XX S CAMPBELL AVE   840
# 3933   4761816    HM370062  11/1/2004 00:05    049XX S WOLCOTT AVE   840
# 4337   4762432    HM372043   6/15/2002 0:00   029XX S MICHIGAN AVE   840
# 4406   4762582    HM368068   4/1/2004 13:40      044XX W CORTEZ ST   840
# 4761   4763189    HM374703   7/1/2004 00:00    043XX S DREXEL BLVD   840
#
# ...

# %% [markdown]
# # Dropping rows where all columns are null

# %%
df.drop([21,125,1325,1539,1603,1777,2290,3918,3933,4337,4406,4761],inplace=True)

# %%
df[df['Location'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID, Case Number, Date, Block, IUCR, Primary Type, Description, Location Description, Arrest, Domestic, Beat, District, Ward, Community Area, FBI Code, X Coordinate, Y Coordinate, Year, Updated On, Latitude, Longitude, Location]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# # Capitalizing the columns

# %%
df.columns= [x.upper() for x in df.columns]  #alternatively, capitalize, title
df
# Out:
#             ID CASE NUMBER             DATE                    BLOCK  IUCR  \
# 0     10000092    HY189866  3/18/2015 19:44          047XX W OHIO ST  041A
# 1     10000094    HY190059  3/18/2015 23:00   066XX S MARSHFIELD AVE  4625
# 2     10000095    HY190052  3/18/2015 22:45    044XX S LAKE PARK AVE   486
# 3     10000096    HY190054  3/18/2015 22:30     051XX S MICHIGAN AVE   460
# 4     10000097    HY189976  3/18/2015 21:00         047XX W ADAMS ST  031A
# ...        ...         ...              ...                      ...   ...
# 4994  10010215    HY199560  3/26/2015 18:30  013XX S BLUE ISLAND AVE  1320
# 4995  10010216    HY199605  3/20/2015 14:00    043XX S LAKE PARK AVE  2820
# 4996  10010218    HY199430  3/22/2015 20:00         0000X E 121ST ST  1320
# 4997  10010219    HY199538  3/26/2015 18:15      083XX S STEWART AVE   860
# 4998  10010220    HY199623  3/26/2015 18:00          003XX W 51ST ST  031A
#
#          PRIMARY TYPE              DESCRIPTION  \
# ...

# %% [markdown]
# # Identifying the Primary Type column

# %%
df['PRIMARY TYPE'].value_counts()
# Out:
# THEFT                               1022
# BATTERY                              937
# CRIMINAL DAMAGE                      560
# NARCOTICS                            559
# ASSAULT                              320
# DECEPTIVE PRACTICE                   317
# OTHER OFFENSE                        310
# BURGLARY                             196
# MOTOR VEHICLE THEFT                  169
# CRIMINAL TRESPASS                    144
# ROBBERY                              139
# WEAPONS VIOLATION                     80
# PUBLIC PEACE VIOLATION                56
# OFFENSE INVOLVING CHILDREN            43
# PROSTITUTION                          28
# INTERFERENCE WITH PUBLIC OFFICER      26
# CRIM SEXUAL ASSAULT                   24
# SEX OFFENSE                           19
# LIQUOR LAW VIOLATION                   8
# HOMICIDE                               8
# ARSON                                  6
# KIDNAPPING                             5
# GAMBLING                               5
# ...

# %% [markdown]
# # Making Primary Type as Index

# %%
df=df.set_index(["PRIMARY TYPE"])

# %% [markdown]
# # Dividing into 2 dataframes based on the weight

# %%
Arrested = df[df["ARREST"]==True]
Not_Arrested = df[df["ARREST"]==False]

# %%
Arrested
# Out:
#                               ID CASE NUMBER             DATE  \
# PRIMARY TYPE
# OTHER OFFENSE           10000094    HY190059  3/18/2015 23:00
# NARCOTICS               10000101    HY190020  3/18/2015 22:09
# WEAPONS VIOLATION       10000109    HY189966  3/18/2015 21:14
# THEFT                   10000111    HY190019  3/18/2015 22:31
# PUBLIC PEACE VIOLATION  10000116    HY190063  3/18/2015 22:56
# ...                          ...         ...              ...
# NARCOTICS               10010201    HY199589  3/26/2015 19:00
# OTHER OFFENSE           10010209    HY199612  3/26/2015 18:53
# ASSAULT                 10010210    HY199565  3/26/2015 18:51
# WEAPONS VIOLATION       10010213    HY199475  3/26/2015 17:26
# THEFT                   10010219    HY199538  3/26/2015 18:15
#
#                                            BLOCK  IUCR  \
# PRIMARY TYPE
# OTHER OFFENSE             066XX S MARSHFIELD AVE  4625
# NARCOTICS                    036XX S WOLCOTT AVE  1811
# ...

# %%
Not_Arrested
# Out:
#                          ID CASE NUMBER             DATE  \
# PRIMARY TYPE
# BATTERY            10000092    HY189866  3/18/2015 19:44
# BATTERY            10000095    HY190052  3/18/2015 22:45
# BATTERY            10000096    HY190054  3/18/2015 22:30
# ROBBERY            10000097    HY189976  3/18/2015 21:00
# BATTERY            10000098    HY190032  3/18/2015 22:00
# ...                     ...         ...              ...
# CRIMINAL TRESPASS  10010214    HY199611  3/26/2015 19:22
# CRIMINAL DAMAGE    10010215    HY199560  3/26/2015 18:30
# OTHER OFFENSE      10010216    HY199605  3/20/2015 14:00
# CRIMINAL DAMAGE    10010218    HY199430  3/22/2015 20:00
# ROBBERY            10010220    HY199623  3/26/2015 18:00
#
#                                      BLOCK  IUCR              DESCRIPTION  \
# PRIMARY TYPE
# BATTERY                    047XX W OHIO ST  041A      AGGRAVATED: HANDGUN
# BATTERY              044XX S LAKE PARK AVE   486  DOMESTIC BATTERY SIMPLE
# ...

# %% [markdown]
# # Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df2=pd.read_csv("CensusPopulations.csv")
df2.head()
# Out:
#    Zip Code  Total Population  Median Age  Total Males  Total Females  \
# 0     91371                 1        73.5            0              1
# 1     90001             57110        26.6        28468          28642
# 2     90002             51223        25.5        24876          26347
# 3     90003             66266        26.3        32631          33635
# 4     90004             62180        34.8        31302          30878
#
#    Total Households  Average Household Size
# 0                 1                    1.00
# 1             12971                    4.40
# 2             11731                    4.36
# 3             15642                    4.22
# 4             22547                    2.73

# %%
plt.scatter(df2['Median Age'],df2['Total Population'],c='red')
plt.xlabel('Median_Age')
plt.ylabel('Population')
plt.title('Age v Population')
# Out:
# Text(0.5, 1.0, 'Age v Population')

# %%
sns.countplot(x=df['ARREST'])
# Out:
# <AxesSubplot:xlabel='ARREST', ylabel='count'>
